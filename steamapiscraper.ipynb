# %%
#pip install steamreviews

# %%
import steamreviews

#Project Zomboid
app_id = 108600
steamreviews.download_reviews_for_app_id(app_id)
# Out:
# [appID = 108600] expected #reviews = 33991
# Number of queries 150 reached. Cooldown: 310 seconds
# Number of queries 150 reached. Cooldown: 310 seconds
# ({'reviews': {'84652123': {'recommendationid': '84652123',
#     'author': {'steamid': '76561198044182675',
#      'num_games_owned': 353,
#      'num_reviews': 47,
#      'playtime_forever': 13850,
#      'playtime_last_two_weeks': 1722,
#      'playtime_at_review': 13850,
#      'last_played': 1610599889},
#     'language': 'english',
# ...

# %%
import json

"data/review_108600.json"

with open("data/review_108600.json") as f:
    data = json.load(f)

len(data['reviews'])
# Out:
# 33990

# %%
import pandas as pd

df = pd.DataFrame(data['reviews'])
df = df.T
df
# Out:
#          recommendationid                                             author  \
# 84652123         84652123  {'steamid': '76561198044182675', 'num_games_ow...
# 84650292         84650292  {'steamid': '76561198189260829', 'num_games_ow...
# 84647357         84647357  {'steamid': '76561197968351158', 'num_games_ow...
# 84646408         84646408  {'steamid': '76561198025117668', 'num_games_ow...
# 84643897         84643897  {'steamid': '76561198024526105', 'num_games_ow...
# ...                   ...                                                ...
# 7602280           7602280  {'steamid': '76561198067098561', 'num_games_ow...
# 7602237           7602237  {'steamid': '76561198043807990', 'num_games_ow...
# 7602221           7602221  {'steamid': '76561197981939207', 'num_games_ow...
# 7602166           7602166  {'steamid': '76561198024263590', 'num_games_ow...
# 7602122           7602122  {'steamid': '76561198003410183', 'num_games_ow...
#
# ...

# %%
# We will use bz2 to compress pickle files to 1/4th the size.

import pickle
import bz2

# This is to compress it.
def compressed_pickle(title, data):
    with bz2.BZ2File(title + '.pbz2', 'w') as f:
        pickle.dump(data, f)
        
# This is to bring it back.        
def decompress_pickle(file):
    data = bz2.BZ2File(file, 'rb')
    data = pickle.load(data)
    return data

# %%
compressed_pickle('data/compressedpz', df)

# %%
df = decompress_pickle('data/compressedpz.pbz2')
